# %%
import requests
import json

# %%
r = open("CalendarBotModel.json","rb")
res = json.load(r)
print(json.dumps(res,indent=4))
# Out:
# {
#     "luis_schema_version": "2.1.0",
#     "versionId": "0.2",
#     "name": "CalendarBotModel",
#     "desc": "",
#     "culture": "en-us",
#     "intents": [
#         {
#             "name": "AddCalendarEntry"
#         },
#         {
#             "name": "CheckAvailability"
#         },
#         {
#             "name": "DeleteCalendarEntry"
#         },
#         {
#             "name": "EditCalendarEntry"
#         },
#         {
#             "name": "Help"
#         },
#         {
#             "name": "Login"
#         },
#         {
#             "name": "None"
#         },
#         {
#             "name": "PrimaryCalendar"
#         },
#         {
#             "name": "ShowCalendarSummary"
#         }
#     ],
#     "entities": [
#         {
#             "name": "CalendarBot.Invitee"
#         },
#         {
#             "name": "CalendarBot.Location"
#         },
#         {
#             "name": "CalendarBot.Subject"
#         },
#         {
# ...

# %%
q = res['entities'][4]
q
# Out:
# {'name': 'EntryVisbility', 'children': ['Private', 'Public']}

# %%
print(q['name'],'\n--',q['children'])
# Out:
# EntryVisbility
# -- ['Private', 'Public']
