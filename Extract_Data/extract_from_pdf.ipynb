# %%
# !pip install PyPDF2
# Out:
# ...
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import PyPDF2
from PyPDF2 import PdfFileReader


pdf =  open('5048229.pdf','rb')
pdf_reader = PyPDF2.PdfFileReader(pdf)
print(pdf_reader.numPages)

page = pdf_reader.getPage(0)

print(page.values)

pdf.close()
# Out:
# 3
# <built-in method values of PageObject object at 0x7fc14468b7d8>

# %%
# !pip install docx
# Out:
# ...
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
pip freeze
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip freeze
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# ...
# WARNING: AstropyDeprecationWarning: astropy.utils.compat.futures is now deprecated - use concurrent.futures instead [astropy.utils.compat.futures]
# WARNING: Logging before flag parsing goes to stderr.
# W0625 06:17:07.979290 140468117473024 logger.py:200] AstropyDeprecationWarning: astropy.utils.compat.futures is now deprecated - use concurrent.futures instead
# ...
# Using TensorFlow backend.
# ...
# Exception ignored in: <_io.FileIO name='/home/nbuser/anaconda3_501/lib/python3.6/site-packages/theano/gof/c_code/lazylinker_c.c' mode='rb' closefd=True>
# ...
# Exception ignored in: <_io.FileIO name='/etc/lsb-release' mode='rb' closefd=True>
# ...
# Exception ignored in: <_io.FileIO name='/home/nbuser/anaconda3_501/lib/python3.6/site-packages/spyder/utils/ipython/templates/blank.html' mode='rb' closefd=True>
# ...

# %%
help('modules docx')
# Out:
# Here is a list of modules whose name or summary contains 'docx'.
# If there are any, enter a module name to get more help.
#
# docx - Open and modify Microsoft Word 2007 docx files (called 'OpenXML' and

# %%
import PyPDF2
PyPDF2.__path__
# Out:
# ['/home/nbuser/anaconda3_501/lib/python3.6/site-packages/PyPDF2']
